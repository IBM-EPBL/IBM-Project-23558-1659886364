# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression

# %% [markdown]
# Load the dataset

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
os.listdir()
# Out:
# ['.config', 'drive', 'sample_data']

# %%
path="drive/MyDrive/Colab Notebooks/dataset"
os.chdir(path)
os.listdir()
# Out:
# ['abalone.csv']

# %%
import pandas as pd
data=pd.read_csv("abalone.csv")

# %%
data
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0      M   0.455     0.365   0.095        0.5140          0.2245
# 1      M   0.350     0.265   0.090        0.2255          0.0995
# 2      F   0.530     0.420   0.135        0.6770          0.2565
# 3      M   0.440     0.365   0.125        0.5160          0.2155
# 4      I   0.330     0.255   0.080        0.2050          0.0895
# ...   ..     ...       ...     ...           ...             ...
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# ...

# %% [markdown]
# Univariate Analysis

# %%
import seaborn as sns
plt.scatter(data.index,data['Sex'])
plt.show()

# %%
plt.scatter(data.index,data['Length'])
plt.show()

# %%
sns.stripplot(y=data['Diameter'])

# %%
sns.stripplot(y=data['Height'])

# %%
sns.stripplot(y=data['Whole weight'])

# %%
plt.scatter(data.index,data['Shucked weight'])
plt.show()

# %%
sns.stripplot(y=data['Viscera weight'])

# %%
sns.stripplot(y=data['Shell weight'])

# %%
plt.scatter(data.index,data['Rings'])
plt.show()

# %% [markdown]
# Bivariate Analysis

# %%
sns.boxplot(x='Sex',y='Rings',data=data)
plt.show()

# %%
sns.violinplot(x="Height",y="Rings",size=8,data=data)
plt.show()

# %%
plt.plot(data["Length"],data["Rings"],'o')
plt.ylabel("Rings")
plt.xlabel("Length")
# Out:
# Text(0.5, 0, 'Length')

# %%
plt.plot(data["Diameter"],data["Rings"],'o')
plt.ylabel("Rings")
plt.xlabel("Diameter")
# Out:
# Text(0.5, 0, 'Diameter')

# %%
plt.plot(data["Whole weight"],data["Rings"],'.')
plt.ylabel("Rings")
plt.xlabel("Length")
# Out:
# Text(0.5, 0, 'Length')

# %%
plt.plot(data["Shell weight"],data["Rings"],'*')
plt.ylabel("Rings")
plt.xlabel("Length")
# Out:
# Text(0.5, 0, 'Length')

# %%
plt.plot(data["Shucked weight"],data["Rings"],'o')
plt.ylabel("Rings")
plt.xlabel("Length")
# Out:
# Text(0.5, 0, 'Length')

# %%
plt.plot(data["Viscera weight"],data["Rings"],'.')
plt.ylabel("Rings")
plt.xlabel("Length")
# Out:
# Text(0.5, 0, 'Length')

# %% [markdown]
# Multivariate Analysis

# %%
sns.pairplot(data,hue="Rings",height=3)
plt.show()

# %% [markdown]
# Descriptive Analysis

# %%
data.describe().T
# Out:
#                  count      mean       std     min     25%     50%     75%  \
# Length          4177.0  0.523992  0.120093  0.0750  0.4500  0.5450   0.615
# Diameter        4177.0  0.407881  0.099240  0.0550  0.3500  0.4250   0.480
# Height          4177.0  0.139516  0.041827  0.0000  0.1150  0.1400   0.165
# Whole weight    4177.0  0.828742  0.490389  0.0020  0.4415  0.7995   1.153
# Shucked weight  4177.0  0.359367  0.221963  0.0010  0.1860  0.3360   0.502
# Viscera weight  4177.0  0.180594  0.109614  0.0005  0.0935  0.1710   0.253
# Shell weight    4177.0  0.238831  0.139203  0.0015  0.1300  0.2340   0.329
# Rings           4177.0  9.933684  3.224169  1.0000  8.0000  9.0000  11.000
#
#                     max
# Length           0.8150
# Diameter         0.6500
# Height           1.1300
# Whole weight     2.8255
# Shucked weight   1.4880
# Viscera weight   0.7600
# Shell weight     1.0050
# Rings           29.0000

# %% [markdown]
# Handling with missing data

# %%
data=pd.DataFrame(data)
data.isnull()
# Out:
#         Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0     False   False     False   False         False           False
# 1     False   False     False   False         False           False
# 2     False   False     False   False         False           False
# 3     False   False     False   False         False           False
# 4     False   False     False   False         False           False
# ...     ...     ...       ...     ...           ...             ...
# 4172  False   False     False   False         False           False
# 4173  False   False     False   False         False           False
# 4174  False   False     False   False         False           False
# 4175  False   False     False   False         False           False
# 4176  False   False     False   False         False           False
#
#       Viscera weight  Shell weight  Rings
# 0              False         False  False
# 1              False         False  False
# ...

# %%
data.fillna(0)
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0      M   0.455     0.365   0.095        0.5140          0.2245
# 1      M   0.350     0.265   0.090        0.2255          0.0995
# 2      F   0.530     0.420   0.135        0.6770          0.2565
# 3      M   0.440     0.365   0.125        0.5160          0.2155
# 4      I   0.330     0.255   0.080        0.2050          0.0895
# ...   ..     ...       ...     ...           ...             ...
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# ...

# %%
data.isnull().sum()
# Out:
# Sex               0
# Length            0
# Diameter          0
# Height            0
# Whole weight      0
# Shucked weight    0
# Viscera weight    0
# Shell weight      0
# Rings             0
# dtype: int64

# %% [markdown]
# Outliers in each attribute

# %%
sns.boxplot(data['Length'],data=data)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.boxplot(data['Diameter'],data=data)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.boxplot(data['Height'],data=data)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.boxplot(data['Whole weight'],data=data)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.boxplot(data['Shucked weight'],data=data)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.boxplot(data['Viscera weight'],data=data)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.boxplot(data['Shell weight'],data=data)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.boxplot(data['Rings'],data=data)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
Q1=data.quantile(0.25)
Q3=data.quantile(0.75)
IQR=Q3-Q1
print(IQR)
# Out:
# Length            0.1650
# Diameter          0.1300
# Height            0.0500
# Whole weight      0.7115
# Shucked weight    0.3160
# Viscera weight    0.1595
# Shell weight      0.1990
# Rings             3.0000
# dtype: float64

# %%
data.shape
# Out:
# (4177, 9)

# %%
upper=np.where(data>=(Q3+1.5*IQR))
lower=np.where(data<=(Q1-1.5*IQR))
data.drop(upper[0],inplace=True)
data.drop(lower[0],inplace=True)
data.shape
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version.  Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version.  Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
# (3781, 9)

# %%
sns.boxplot(data['Length'],data=data)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.boxplot(data['Rings'],data=data)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.boxplot(data['Height'],data=data)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.boxplot(data['Diameter'],data=data)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.boxplot(data['Whole weight'],data=data)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.boxplot(data['Shucked weight'],data=data)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.boxplot(data['Shell weight'],data=data)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.boxplot(data['Viscera weight'],data=data)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# Label encoding for categorial data

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler

from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn import metrics

# %%
le=LabelEncoder()
data['Sex']=le.fit_transform(data['Sex'])

# %%
data
# Out:
#       Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0       2   0.455     0.365   0.095        0.5140          0.2245
# 1       2   0.350     0.265   0.090        0.2255          0.0995
# 2       0   0.530     0.420   0.135        0.6770          0.2565
# 3       2   0.440     0.365   0.125        0.5160          0.2155
# 4       1   0.330     0.255   0.080        0.2050          0.0895
# ...   ...     ...       ...     ...           ...             ...
# 4172    0   0.565     0.450   0.165        0.8870          0.3700
# 4173    2   0.590     0.440   0.135        0.9660          0.4390
# 4174    2   0.600     0.475   0.205        1.1760          0.5255
# 4175    0   0.625     0.485   0.150        1.0945          0.5310
# 4176    2   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# ...

# %% [markdown]
# Split the data into dependent and independent variables

# %%
x=data.iloc[:,:5]
x
# Out:
#       Sex  Length  Diameter  Height  Whole weight
# 0       2   0.455     0.365   0.095        0.5140
# 1       2   0.350     0.265   0.090        0.2255
# 2       0   0.530     0.420   0.135        0.6770
# 3       2   0.440     0.365   0.125        0.5160
# 4       1   0.330     0.255   0.080        0.2050
# ...   ...     ...       ...     ...           ...
# 4172    0   0.565     0.450   0.165        0.8870
# 4173    2   0.590     0.440   0.135        0.9660
# 4174    2   0.600     0.475   0.205        1.1760
# 4175    0   0.625     0.485   0.150        1.0945
# 4176    2   0.710     0.555   0.195        1.9485
#
# [3781 rows x 5 columns]

# %%
y=data.iloc[:,5:]
y
# Out:
#       Shucked weight  Viscera weight  Shell weight  Rings
# 0             0.2245          0.1010        0.1500     15
# 1             0.0995          0.0485        0.0700      7
# 2             0.2565          0.1415        0.2100      9
# 3             0.2155          0.1140        0.1550     10
# 4             0.0895          0.0395        0.0550      7
# ...              ...             ...           ...    ...
# 4172          0.3700          0.2390        0.2490     11
# 4173          0.4390          0.2145        0.2605     10
# 4174          0.5255          0.2875        0.3080      9
# 4175          0.5310          0.2610        0.2960     10
# 4176          0.9455          0.3765        0.4950     12
#
# [3781 rows x 4 columns]

# %%
y=data.iloc[:,4:]
y
# Out:
#       Whole weight  Shucked weight  Viscera weight  Shell weight  Rings
# 0           0.5140          0.2245          0.1010        0.1500     15
# 1           0.2255          0.0995          0.0485        0.0700      7
# 2           0.6770          0.2565          0.1415        0.2100      9
# 3           0.5160          0.2155          0.1140        0.1550     10
# 4           0.2050          0.0895          0.0395        0.0550      7
# ...            ...             ...             ...           ...    ...
# 4172        0.8870          0.3700          0.2390        0.2490     11
# 4173        0.9660          0.4390          0.2145        0.2605     10
# 4174        1.1760          0.5255          0.2875        0.3080      9
# 4175        1.0945          0.5310          0.2610        0.2960     10
# 4176        1.9485          0.9455          0.3765        0.4950     12
#
# [3781 rows x 5 columns]

# %%
x=data.iloc[:,:3]
x
# Out:
#       Sex  Length  Diameter
# 0       2   0.455     0.365
# 1       2   0.350     0.265
# 2       0   0.530     0.420
# 3       2   0.440     0.365
# 4       1   0.330     0.255
# ...   ...     ...       ...
# 4172    0   0.565     0.450
# 4173    2   0.590     0.440
# 4174    2   0.600     0.475
# 4175    0   0.625     0.485
# 4176    2   0.710     0.555
#
# [3781 rows x 3 columns]

# %% [markdown]
# Scaling independent variables

# %%
scaler=StandardScaler()
scaler.fit(data)
# Out:
# StandardScaler()

# %% [markdown]
# Split the data into training and testing

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.4)

# %%
x_train.shape
# Out:
# (2268, 3)

# %%
x_test.shape
# Out:
# (1513, 3)

# %%
y_train.shape
# Out:
# (2268, 5)

# %%
y_test.shape
# Out:
# (1513, 5)

# %% [markdown]
# Build the model

# %%
from sklearn.linear_model import LinearRegression
model1=LinearRegression()
model1.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
x_pred2=model1.predict(x_test)

# %%
x_pred2
# Out:
# array([[ 0.54293128,  0.24351859,  0.12147294,  0.15191496,  8.24259532],
#        [ 1.38249301,  0.61190958,  0.30405563,  0.38540048, 11.23426349],
#        [ 1.15711841,  0.51575114,  0.25382398,  0.32251017, 10.47264387],
#        ...,
#        [ 0.63608507,  0.28146944,  0.1407414 ,  0.18036454,  8.7195884 ],
#        [ 1.41044323,  0.61048661,  0.30764389,  0.40291291, 11.83575567],
#        [ 1.08937455,  0.47508182,  0.23967424,  0.30885909, 10.4199853 ]])

# %% [markdown]
# Train the model

# %%
x_train[0:4]
# Out:
#       Sex  Length  Diameter
# 2407    1   0.625      0.43
# 2719    1   0.360      0.26
# 738     2   0.535      0.41
# 824     1   0.385      0.30

# %%
y_train[0:9]
# Out:
#       Whole weight  Shucked weight  Viscera weight  Shell weight  Rings
# 2407        1.4110          0.5720          0.2970        0.3950     12
# 2719        0.1795          0.0740          0.0315        0.0600      5
# 738         0.8620          0.2855          0.1525        0.3200     14
# 824         0.2895          0.1215          0.0630        0.0900      7
# 66          0.9150          0.3540          0.1935        0.3200     12
# 3766        0.8460          0.3460          0.1715        0.2735     10
# 65          0.4800          0.2340          0.1015        0.1350      8
# 3099        0.9465          0.4355          0.2605        0.2505      9
# 608         0.2280          0.0675          0.0675        0.0810     10

# %% [markdown]
# Test the model

# %%
y_test[0:1]
# Out:
#       Whole weight  Shucked weight  Viscera weight  Shell weight  Rings
# 1268         0.346          0.1425           0.073         0.113     11

# %%
x_test[0:7]
# Out:
#       Sex  Length  Diameter
# 1268    1   0.465     0.340
# 510     1   0.680     0.530
# 3394    2   0.620     0.480
# 596     0   0.550     0.430
# 3968    1   0.375     0.290
# 3343    0   0.455     0.365
# 2842    2   0.600     0.475

# %% [markdown]
# Measure the performance using metrics

# %%
x_test[0:9]
# Out:
#       Sex  Length  Diameter
# 1268    1   0.465     0.340
# 510     1   0.680     0.530
# 3394    2   0.620     0.480
# 596     0   0.550     0.430
# 3968    1   0.375     0.290
# 3343    0   0.455     0.365
# 2842    2   0.600     0.475
# 133     1   0.350     0.260
# 1903    2   0.575     0.445
